# %%
from novelpy import Disruptiveness

disruptiveness = Disruptiveness(
   #client_name = 'mongodb://Pierre:ilovebeta67@localhost:27017',
   #db_name =  'novelty_final',
   collection_name = 'Citation_network',
   focal_year = 2000,
   id_variable = 'PMID',
   refs_list_variable ='refs',
   cits_list_variable ='cited_by',
   year_variable = 'year')


disruptiveness.get_indicators(parallel = False)
# Out:
# Load citation network ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14012/4200206468.py in <module>
#      12
#      13
# ---> 14 disruptiveness.get_indicators(parallel = False)
#
# ~\Documents\GitHub\novelpy\novelpy\indicators\WuBuBornmann.py in get_indicators(self, parallel)
#     385         if not self.tomongo:
#     386             print("Load citation network ...")
# --> 387             self.get_citation_network()
#     388             self.papers_items = {pmid:self.citation_network[pmid] for pmid in self.citation_network if self.citation_network[pmid][self.year_variable] == self.focal_year}
#     389         else:
#
# ~\Documents\GitHub\novelpy\novelpy\indicators\WuBuBornmann.py in get_citation_network(self)
#      96
#      97         """
# ...

# %%
a = {'ab':120}
a= None
'ab' in a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12940/1714297394.py in <module>
#       1 a = {'ab':120}
#       2 a= None
# ----> 3 'ab' in a
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
'DI1': (len_I-len_J)/(len_I+len_J+len_K) if any([len_I,len_J,len_K !=0]) else 0,
'DI5': (len_I-len_J5)/(len_I+len_J5+len_K)if any([len_I,len_J5,len_K !=0]) else 0,
'DI5nok': (len_I-len_J5)/(len_I+len_J5) if any([len_I,len_J5 !=0]) else 0,
'DI1nok': (len_I-len_J)/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
'DeIn': sum_Jxc/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
'Breadth' : len_B/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
'Depth' : len_D/(len_I+len_J) if any([len_I,len_J !=0]) else 0

# %%
disruptiveness_indicators
# Out:
# {'disruptiveness': {'DI1': 0.4,
#   'DI5': 0.75,
#   'DI5nok': 1.0,
#   'DI1nok': 0.5,
#   'DeIn': 0.25,
#   'Breadth': 0.5,
#   'Depth': 0.5}}

# %%
Breadth
# Out:
# [2, 8]

# %%
focal_paper_id = 1
focal_paper_refs = [5,4]
focal_paper_cits =  [2,3,8,6]

citation_network = {1:{'citations':{'refs': [5,4],
'cited_by': [2,3,8,6]},
 'year':3},
 
 
 
 # papers that cite the focal paper that also cite reference from the focal paper

2:{'citations':{'refs': [1,4],
    'cited_by': [3]},
 'year':3},
# papers that cite the focal paper but do not cite reference from the focal paper

3:{'citations':{'refs': [1,2],
    'cited_by': [6]},
 'year':4},
# papers that do not cite the focal paper but cite reference from the focal paper

7:{'citations':{'refs': [4,5],
    'cited_by': [8]},
 'year':4},
# papers that cite the focal paper that do not cite papers that cite the focal paper

8:{'citations':{'refs': [1,7],
    'cited_by': [6]},
 'year':4},
# papers that cite the focal paper that cite at least one other paper that cite the focal paper
6:{'citations':{'refs': [1,3,8],
    'cited_by': []},
 'year':5},
 
4:{'citations':{'refs': [-1],
    'cited_by': [1,2,7]},
 'year':1},


5:{'citations':{'refs': [4],
    'cited_by': [1,7]},
 'year':2}}

# %%
def  get_citing_focal_p(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network):
    docs = dict()
    ids = set()
    for citer in focal_paper_cits:
        #try:
        if citer not in ids:
            doc = citation_network[citer]
            docs.update({citer: doc['citations']['refs']})
            ids.update([citer])
    return docs

# %timeit get_citing_focal_p(focal_paper_id,focal_paper_refs,focal_paper_cits,citation_network)
# Out:
# 2.7 µs ± 211 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
get_citing_focal_p(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network)
# Out:
# {2: [1, 4], 3: [1, 2], 8: [1, 7], 5: [4]}

# %%
get_citing_focal_p(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network)
# Out:
# {2: [1, 4], 3: [1, 2], 8: [1, 7], 5: [4]}

# %%
def  get_citing_focal_p(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network):
    docs = []
    
    for citer in focal_paper_cits:
        #try:
        doc = citation_network[citer]
        docs.append({'pmid':citer,
                     'refs': doc['citations']['refs']})
    #print(docs)
    citing_focal_paper =  pd.DataFrame(docs).drop_duplicates('pmid')
    #print(citing_ref_from_focal_paper)
    citing_focal_paper = {
        row['pmid']:row['refs'] for index, row in citing_focal_paper.iterrows()
        }
    #print(citing_focal_paper)
    return citing_focal_paper

# %timeit get_citing_focal_p(focal_paper_id,focal_paper_refs,focal_paper_cits,citation_network)
# Out:
# 1.64 ms ± 41.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def  get_citing_ref_fp(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network,focal_year):
    docs = []
    for ref in focal_paper_refs:
            citing_ref_from_fp = citation_network[ref]['citations']['cited_by']
            for citing_paper in citing_ref_from_fp :
                if citing_paper != focal_paper_id:
                    citing_paper_doc = citation_network[citing_paper]
                    if citing_paper_doc['year'] >= focal_year:
                        citers_refs = citation_network[citing_paper]['citations']['refs']
                        docs.append({'pmid':citing_paper,
                                     'refs': citers_refs})
        
            #except:
        #    pass

    citing_ref_from_focal_paper = pd.DataFrame(docs).drop_duplicates('pmid')
    
    citing_ref_from_focal_paper = {
        row['pmid']:row['refs'] for index, row in citing_ref_from_focal_paper.iterrows()
        }
    return citing_ref_from_focal_paper

# %timeit get_citing_focal_p(focal_paper_id,focal_paper_refs,focal_paper_cits,citation_network)
# Out:
# 2.46 µs ± 165 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
 get_citing_ref_fp(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network,2)
# Out:
# {7: [4, 5], 2: [1, 4]}

# %%
def  get_citing_ref_fp(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network,focal_year):
    citing_ref_from_focal_paper = dict()
    ids = set()
    for ref in focal_paper_refs:
            citing_ref_from_fp = citation_network[ref]['citations']['cited_by']
            for citing_paper in citing_ref_from_fp :
                if citing_paper != focal_paper_id and citing_paper not in ids:
                    citing_paper_doc = citation_network[citing_paper]
                    if citing_paper_doc['year'] >= focal_year:
                        citers_refs = citation_network[citing_paper]['citations']['refs']
                        citing_ref_from_focal_paper.update({citing_paper: citers_refs})
                        ids.update([citing_paper])
            #except:
        #    pass
    return citing_ref_from_focal_paper

# %timeit get_citing_focal_p(focal_paper_id,focal_paper_refs,focal_paper_cits,citation_network)
# Out:
# 2.43 µs ± 96.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
get_citing_ref_fp(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network,3)
# Out:
# {7: [4, 5], 2: [1, 4]}

# %%
get_disruptiveness(focal_paper_id,
                        focal_paper_refs,
                        focal_paper_cits,
                        citation_network)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17248/2266443482.py in <module>
# ----> 1 get_disruptiveness(focal_paper_id,
#       2                         focal_paper_refs,
#       3                         focal_paper_cits,
#       4                         citation_network)
#
# NameError: name 'focal_paper_id' is not defined

# %%
import pandas as pd
focal_year = 3
# papers that cites our focal paper
citing_focal_paper = dict()
ids = set()
for citer in focal_paper_cits:
    #try:
    if citer not in ids:
        doc = citation_network[citer]
        citing_focal_paper.update({citer: doc['citations']['refs']})
        ids.update([citer])
# papers that cite refs from focal paper

citing_ref_from_focal_paper = dict()
ids = set()
for ref in focal_paper_refs:
        citing_ref_from_fp = citation_network[ref]['citations']['cited_by']
        for citing_paper in citing_ref_from_fp :
            if citing_paper != focal_paper_id and citing_paper not in ids:
                citing_paper_doc = citation_network[citing_paper]
                if citing_paper_doc['year'] >= focal_year:
                    citers_refs = citation_network[citing_paper]['citations']['refs']
                    citing_ref_from_focal_paper.update({citing_paper: citers_refs})
                    ids.update([citing_paper])
# papers that cite the focal paper that also cite reference from the focal paper
J = set(citing_focal_paper.keys()).intersection(citing_ref_from_focal_paper.keys())

# papers that cite the focal paper but do not cite reference from the focal paper
I = set(citing_focal_paper.keys()) - J

# papers that do not cite the focal paper but cite reference from the focal paper
K = set(citing_ref_from_focal_paper.keys()) - J

# number of reference cited by a paper that cite the focal paper that are cited by the focal paper
Jxc = [len(set(focal_paper_refs).intersection(cited_ref)) for cited_ref in citing_focal_paper.values()]

# keep papers that cite the focal paper that share at least 5 references with the focal paper
J5 = [len_match_ref for len_match_ref in Jxc if len_match_ref > 4]

# papers that cite the focal paper that do not cite papers that cite the focal paper
Breadth = [pmid for pmid in citing_focal_paper
           if not any([ref in citing_focal_paper.keys() for ref in citing_focal_paper[pmid]])]

# papers that cite the focal paper that cite at least one other paper that cite the focal paper
Depth = [pmid for pmid in citing_focal_paper
           if any([ref in citing_focal_paper.keys() for ref in citing_focal_paper[pmid]])]

len_I = len(I) if I else 0
len_J = len(J) if J else 0
len_J5 = len(J5) if J5 else 0
len_K = len(K) if K else 0
sum_Jxc = sum(Jxc) if Jxc else 0
len_B = len(Breadth) if Breadth else 0
len_D = len(Depth) if Depth else 0

disruptiveness_indicators = {
    'disruptiveness' : {
        'DI1': (len_I-len_J)/(len_I+len_J+len_K) if any([len_I,len_J,len_K !=0]) else 0,
        'DI5': (len_I-len_J5)/(len_I+len_J5+len_K)if any([len_I,len_J5,len_K !=0]) else 0,
        'DI5nok': (len_I-len_J5)/(len_I+len_J5) if any([len_I,len_J5 !=0]) else 0,
        'DI1nok': (len_I-len_J)/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
        'DeIn': sum_Jxc/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
        'Breadth' : len_B/(len_I+len_J) if any([len_I,len_J !=0]) else 0,
        'Depth' : len_D/(len_I+len_J) if any([len_I,len_J !=0]) else 0
        }
    }

# %%
# %timeit get_disruptiveness(focal_paper_id,focal_paper_refs,focal_paper_cits,citation_network)
# Out:
# 2.88 ms ± 45.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
test = {10592257: {'year': 2000,
  'citations': {'refs': [1776175,
    2186365,
    7917334,
    9397688,
    9399874,
    9847211,
    10361093,
    10592254],
   'cited_by': [11099260,
    11564824,
    11587767,
    11668637,
    11752326,
    12050125,
    15699492,
    15689328,
    18678798,
    23592781,
    23818228,
    26455820]}},10594130: {'year': 2000,
  'citations': {'refs': [409281,
    427670,
    468126,
    575283,
    578869,
    702236,
    790898,
    1172656,
    1383898,
    1581045,
    1607708,
    2417934,
    2693662,
    3528291,
    3959097,
    4359735,
    5919360,
    6240021,
    6345466,
    6395954,
    6990771,
    7004181,
    7188702,
    7351601,
    7495683,
    7515561,
    7524628,
    8013522,
    8135634,
    8666682,
    8803890],
   'cited_by': [15685595, 17383357, 22670176]}}}

# %%
from novelpy import create_output

co = create_output(
            client_name = 'mongodb://localhost:27017',
   db_name =  'novelpy',
   collection_name = 'Citation_network',
            id_variable = 'PMID',
            year_variable = 'year',
            variable = 'refs_pmid_wos',
            focal_year = 2000)

# %%
co.papers_items
# Out:
# {10473999: [2083495, 2289942],
#  10474000: [2195956,
#   3883975,
#   3941580,
#   6633118,
#   7224509,
#   7295161,
#   7458140,
#   7501374,
#   7501395,
#   7564842,
#   7564843,
#   8215100,
#   9059865,
#   9472577],
#  10474001: [709213, 892681, 1164643, 3744203, 9621907],
#  10474006: [661460,
#   1463112,
#   2070531,
#   2073758,
#   2233085,
#   2282704,
#   2755293,
#   3432387,
#   3669839,
#   3999077,
#   4432754,
#   6716991,
#   6756263,
#   7224509,
#   7458140,
#   7879628,
#   7994884,
#   8182320,
#   8239351,
#   8246662,
#   8286099,
#   8365004,
#   8484938,
#   8652152,
#   8665707,
#   8665717,
#   8877200,
#   8877233,
#   8889308,
#   8932945,
#   9305247,
#   9442833,
#   9473078,
#   9638466,
#   9649080,
#   9840514,
#   10037283,
#   10190800],
#  10474002: [791049, 4811577, 13636585],
#  10474007: [621230,
#   945807,
#   1036385,
#   1447920,
#   1744192,
#   3434132,
#   3434134,
#   3745333,
#   4015960,
#   5065080,
#   6925853,
#   7201047,
# ...

# %%
from novelpy import Disruptiveness

disruptiveness = Disruptiveness(
   client_name = 'mongodb://localhost:27017',
   db_name =  'novelpy',
   collection_name = 'Citation_network',
   focal_year = 2000,
   id_variable = 'PMID',
   refs_list_variable ='refs',
   cits_list_variable ='cited_by',
   year_variable = 'year')

# %%
from novelpy import Disruptiveness

# %%
from novelpy.indicators.Author_proximity import Author_proximity

# for year in range(2000,2011):
author =  Author_proximity(client_name = 'mongodb://Pierre:ilovebeta67@localhost:27017/',
                     db_name = 'novelty_final',
                     collection_name = 'articles',
                     id_variable = 'PMID',
                     year_variable = 'year',
                     aut_list_variable = 'a02_authorlist',
                     aut_id_variable = 'AID',
                     entity = ['title','abstract'],
                     focal_year = 2003,
                     windows_size = 5)
author.load_data()

# %%
doc= author.collection.find({'PMID':12906532})

# %%
doc= author.collection.find({'PMID':12901651})

# %%
author.compute_score(doc[0])
# Out:
#   5%|███▋                                                                             | 24/521 [00:10<03:46,  2.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10448/3978491233.py in <module>
# ----> 1 author.compute_score(doc[0])
#
# ~\Documents\GitHub\novelpy\novelpy\indicators\Author_proximity.py in compute_score(self, doc)
#     485
#     486                 if self.nb_aut > 1:
# --> 487                     self.get_inter_dist(ent)
#     488                     self.structure_infos(ent)
#     489
#
# ~\Documents\GitHub\novelpy\novelpy\indicators\Author_proximity.py in get_inter_dist(self, ent)
#     445                         j_items.append(j_item)
#     446
# --> 447                 inter_paper_dist = (1-cdist(np.array(items),np.array(j_items), metric='cosine')).tolist()
# ...

# %%
author.infos
# Out:
# {'authors_novelty_title_5': {'individuals_scores': [{'AID': 8198100,
#     'stats': {'mean': 0.31808810792122333,
#      'sd': 0.08553585716074315,
#      'median': 0.3085945701966156,
#      'nb_comb': 10}},
#    {'AID': 6243729,
#     'stats': {'mean': 0.3319597706200684,
#      'sd': 0.12884974792506085,
#      'median': 0.31874808309005986,
#      'nb_comb': 55}}],
#   'iter_individuals_scores': [{'ids': [8198100, 6243729],
#     'stats': {'mean': 0.5805076724972337,
#      'sd': 0.1159232272027977,
#      'median': 0.5740010620294947,
#      'nb_comb': 55}}],
#   'share_nb_aut_captured': 1.0},
#  'authors_novelty_abstract_5': {'individuals_scores': [{'AID': 8198100,
#     'stats': {'mean': 0.14609241031584164,
#      'sd': 0.044850955097400655,
#      'median': 0.1607131594138817,
#      'nb_comb': 10}},
#    {'AID': 6243729,
#     'stats': {'mean': 0.1610922867922084,
#      'sd': 0.06451840016891992,
#      'median': 0.15205928847797312,
#      'nb_comb': 55}}],
# ...

# %%
author.infos
# Out:
# {'authors_novelty_title_5': {'individuals_scores': [{'AID': 8198100,
#     'stats': {'mean': 0.31808810792122333,
#      'sd': 0.08553585716074315,
#      'median': 0.3085945701966156,
#      'nb_comb': 10}},
#    {'AID': 6243729,
#     'stats': {'mean': 0.3319597706200684,
#      'sd': 0.12884974792506085,
#      'median': 0.31874808309005986,
#      'nb_comb': 55}}],
#   'iter_individuals_scores': [{'ids': [8198100, 6243729],
#     'stats': {'mean': 0.5805076724972335,
#      'sd': 0.11592322720279774,
#      'median': 0.5740010620294945,
#      'nb_comb': 55}}],
#   'share_nb_aut_captured': 1.0},
#  'authors_novelty_abstract_5': {'individuals_scores': [{'AID': 8198100,
#     'stats': {'mean': 0.14609241031584164,
#      'sd': 0.044850955097400655,
#      'median': 0.1607131594138817,
#      'nb_comb': 10}},
#    {'AID': 6243729,
#     'stats': {'mean': 0.1610922867922084,
#      'sd': 0.06451840016891992,
#      'median': 0.15205928847797312,
#      'nb_comb': 55}}],
# ...

# %%
author.compute_score(doc[0])
# Out:
# 0
# 100%|████████████████████████████████████████████████████████████████████████████████| 520/520 [00:06<00:00, 84.90it/s]
# 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 519/519 [00:32<00:00, 16.16it/s]
# 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 518/518 [00:40<00:00, 12.75it/s]
# 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 517/517 [00:33<00:00, 15.58it/s]
# 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 516/516 [00:07<00:00, 67.15it/s]
# 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 515/515 [00:33<00:00, 15.50it/s]
# 6
# 100%|████████████████████████████████████████████████████████████████████████████████| 514/514 [00:29<00:00, 17.38it/s]
# 7
# ...

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
comb = np.array([list(range(200)),list(range(102,302))])
comb2 = np.array([list(range(200,400)),list(range(500,700)),list(range(500,700))])
inter_paper_dist = cosine_similarity(comb)[0,1]
inter_paper_dist
a = []

# %%
from scipy.spatial.distance import cdist
(1-cdist(comb2,comb,metric = 'cosine')).tolist()
# Out:
# [[0.9443006171014879, 0.9960763708480744],
#  [0.9090663803307769, 0.9832951165529628],
#  [0.9090663803307769, 0.9832951165529628]]
